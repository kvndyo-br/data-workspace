# %%
import sys
print(sys.executable)
# Out:
# C:\Users\User\python\.venv\Scripts\python.exe

# %%
import numpy as np
import pandas as pd

data = pd.DataFrame({
    "Name": ["A", "B", "C"],
    "Score": [75, 82, 91]
})

print(data)
print("\nAverage score:", data["Score"].mean())
# Out:
#   Name  Score
# 0    A     75
# 1    B     82
# 2    C     91
#
# Average score: 82.66666666666667
